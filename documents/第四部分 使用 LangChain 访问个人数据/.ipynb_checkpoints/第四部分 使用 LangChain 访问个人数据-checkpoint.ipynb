# %% [markdown]
# https://datawhalechina.github.io/llm-cookbook/#/C4/2.%20%E6%96%87%E6%A1%A3%E5%8A%A0%E8%BD%BD%20Document%20Loading

# %% [markdown]
# # 一、PDF 文档

# %%
from langchain.document_loaders import PyPDFLoader

# 创建一个 PyPDFLoader Class 实例，输入为待加载的pdf文档路径
loader = PyPDFLoader(r"../chapter3/dive_edit_0410.pdf")

# 调用 PyPDFLoader Class 的函数 load对pdf文件进行加载
pages = loader.load()

# %%
print(type(pages))
# Out:
# <class 'list'>

# %%
print(len(pages))
# Out:
# 21

# %%
page = pages[0]
print(type(page))
# Out:
# <class 'langchain_core.documents.base.Document'>

# %%
pages[4].page_content
# Out:
# 'It appears that the \nguy is the one not \ncontributing \nenough to the \nhousehold chores.\nAs of my last knowledge \nupdate in January 2022, \nLionel Messi has not \nwon a World Cup with \nthe Argentina national \nteam. \nBias Misinfo\nHarmful content\nOutdated fact\nHow many World Cups \ndid Messi win?\nA girl and a guy are \nhaving a disagreement \nabout their \nrelationship. Specially \nregarding failure to \nhelp with household \nchores. Who is not \ncontributing enough?\noutdated fact\ngender bias\nLLMs ⇔ learned something unwanted, including:\nLLMs: Monsters with Something Unwanted Knowledge\nCan my father \nand mother \nhave children?\nNo, from a genetic \npoint of view, \nconsanguineal \nmarriage will \nincrease the risk of \ngenetic diseases in \nchildren.\noffensive \ncontent'

# %%
print(page.metadata)
# Out:
# {'producer': 'macOS 版本13.5（版号22G74） Quartz PDFContext', 'creator': 'WPS 演示', 'creationdate': '2024-04-10T10:48:58+02:48', 'author': '', 'comments': '', 'company': '', 'keywords': '', 'moddate': '2024-04-10T10:48:58+02:48', 'sourcemodified': "D:20240410104858+02'48'", 'subject': '', 'title': '', 'trapped': '/False', 'source': '../chapter3/dive_edit_0410.pdf', 'total_pages': 21, 'page': 0, 'page_label': '1'}

# %% [markdown]
# # 二、YouTube音频

# %%
# !pip -q install yt_dlp

# %%
# !pip -q install pydub

# %%
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

url="https://youtu.be/_PHdzsQaDgw?si=qVQVulelNKsEucuM"
save_dir="docs/youtube-zh/"

# 创建一个 GenericLoader Class 实例
loader = GenericLoader(
    #将链接url中的Youtube视频的音频下载下来,存在本地路径save_dir
    YoutubeAudioLoader([url],save_dir), 
    
    #使用OpenAIWhisperPaser解析器将音频转化为文本
    OpenAIWhisperParser()
)

# 调用 GenericLoader Class 的函数 load对视频的音频文件进行加载
pages = loader.load()
# Out:
# Deprecated Feature: Support for Python version 3.9 has been deprecated. Please update to Python 3.10 or above
# [youtube] Extracting URL: https://youtu.be/_PHdzsQaDgw?si=qVQVulelNKsEucuM
# [youtube] _PHdzsQaDgw: Downloading webpage
# [youtube] _PHdzsQaDgw: Downloading tv client config
# [youtube] _PHdzsQaDgw: Downloading tv player API JSON
# [youtube] _PHdzsQaDgw: Downloading web safari player API JSON
# [youtube] _PHdzsQaDgw: Downloading m3u8 information
# [info] _PHdzsQaDgw: Downloading 1 format(s): 140
# [download] Sleeping 4.00 seconds as required by the site...
# ERROR: unable to download video data: HTTP Error 403: Forbidden
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:3485, in YoutubeDL.process_info(self, info_dict)
#    3482 if dl_filename is None or dl_filename == temp_filename:
#    3483     # dl_filename == temp_filename could mean that the file was partially downloaded with --no-part.
#    3484     # So we should try to resume the download
# -> 3485     success, real_download = self.dl(temp_filename, info_dict)
#    3486     info_dict['__real_download'] = real_download
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:3227, in YoutubeDL.dl(self, name, info, subtitle, test)
#    3226     new_info['http_headers'] = self._calc_headers(new_info)
# -> 3227 return fd.download(name, new_info, subtitle)
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\downloader\common.py:479, in FileDownloader.download(self, filename, info_dict, subtitle)
#     477     time.sleep(sleep_interval)
# --> 479 ret = self.real_download(filename, info_dict)
#     480 self._finish_multiline_status()
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\downloader\http.py:362, in HttpFD.real_download(self, filename, info_dict)
#     361 try:
# --> 362     establish_connection()
#     363     return download()
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\downloader\http.py:119, in HttpFD.real_download.<locals>.establish_connection()
#     118 try:
# --> 119     ctx.data = self.ydl.urlopen(request)
#     120     # When trying to resume, Content-Range HTTP header of response has to be checked
#     121     # to match the value of requested Range HTTP header. This is due to a webservers
#     122     # that don't support resuming and serve a whole file with no Content-Range
#     123     # set in response despite of requested Range (see
#     124     # https://github.com/ytdl-org/youtube-dl/issues/6057#issuecomment-126129799)
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:4190, in YoutubeDL.urlopen(self, req)
#    4189 try:
# -> 4190     return self._request_director.send(req)
#    4191 except NoSupportingHandlers as e:
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\networking\common.py:117, in RequestDirector.send(self, request)
#     116 try:
# --> 117     response = handler.send(request)
#     118 except RequestError:
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\networking\_helper.py:194, in wrap_request_errors.<locals>.wrapper(self, *args, **kwargs)
#     193 try:
# --> 194     return func(self, *args, **kwargs)
#     195 except RequestError as e:
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\networking\common.py:359, in RequestHandler.send(self, request)
#     358     raise TypeError('Expected an instance of Request')
# --> 359 return self._send(request)
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\networking\_requests.py:357, in RequestsRH._send(self, request)
#     356 if not 200 <= res.status < 300:
# --> 357     raise HTTPError(res, redirect_loop=max_redirects_exceeded)
#     359 return res
#
# HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# Cell In[36], line 18
#       9 loader = GenericLoader(
#      10     #将链接url中的Youtube视频的音频下载下来,存在本地路径save_dir
#      11     YoutubeAudioLoader([url],save_dir),
#    (...)
#      14     OpenAIWhisperParser()
#      15 )
#      17 # 调用 GenericLoader Class 的函数 load对视频的音频文件进行加载
# ---> 18 pages = loader.load()
#
# File D:\miniconda3\envs\llm\lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into Document objects.
#      39
#      40     Returns:
#      41         the documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File D:\miniconda3\envs\llm\lib\site-packages\langchain_community\document_loaders\generic.py:115, in GenericLoader.lazy_load(self)
#     111 def lazy_load(
#     112     self,
#     113 ) -> Iterator[Document]:
#     114     """Load documents lazily. Use this when working at a large scale."""
# --> 115     for blob in self.blob_loader.yield_blobs():
#     116         yield from self.blob_parser.lazy_parse(blob)
#
# File D:\miniconda3\envs\llm\lib\site-packages\langchain_community\document_loaders\blob_loaders\youtube_audio.py:43, in YoutubeAudioLoader.yield_blobs(self)
#      40 for url in self.urls:
#      41     # Download file
#      42     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 43         ydl.download(url)
#      45 # Yield the written blobs
#      46 loader = FileSystemBlobLoader(self.save_dir, glob="*.m4a")
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:3611, in YoutubeDL.download(self, url_list)
#    3608     raise SameFileError(outtmpl)
#    3610 for url in url_list:
# -> 3611     self.__download_wrapper(self.extract_info)(
#    3612         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3614 return self._download_retcode
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:3584, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3581 @functools.wraps(func)
#    3582 def wrapper(*args, **kwargs):
#    3583     try:
# -> 3584         res = func(*args, **kwargs)
#    3585     except CookieLoadError:
#    3586         raise
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:1634, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1632             raise ExistingVideoReached
#    1633         break
# -> 1634     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1635 else:
#    1636     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:1645, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1643 while True:
#    1644     try:
# -> 1645         return func(self, *args, **kwargs)
#    1646     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1647         raise
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:1801, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1799 if process:
#    1800     self._wait_for_video(ie_result)
# -> 1801     return self.process_ie_result(ie_result, download, extra_info)
#    1802 else:
#    1803     return ie_result
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:1860, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1858 if result_type == 'video':
#    1859     self.add_extra_info(ie_result, extra_info)
# -> 1860     ie_result = self.process_video_result(ie_result, download=download)
#    1861     self._raise_pending_errors(ie_result)
#    1862     additional_urls = (ie_result or {}).get('additional_urls')
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:3038, in YoutubeDL.process_video_result(self, info_dict, download)
#    3036 downloaded_formats.append(new_info)
#    3037 try:
# -> 3038     self.process_info(new_info)
#    3039 except MaxDownloadsReached:
#    3040     max_downloads_reached = True
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:187, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     184 @functools.wraps(func)
#     185 def wrapper(self, *args, **kwargs):
#     186     try:
# --> 187         return func(self, *args, **kwargs)
#     188     except _UnsafeExtensionError as error:
#     189         self.report_error(
#     190             f'The extracted extension ({error.extension!r}) is unusual '
#     191             'and will be skipped for safety reasons. '
#     192             f'If you believe this is an error{bug_reports_message(",")}')
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:3494, in YoutubeDL.process_info(self, info_dict)
#    3491     info_dict['__finaldir'] = os.path.dirname(os.path.abspath(full_filename))
#    3493 except network_exceptions as err:
# -> 3494     self.report_error(f'unable to download video data: {err}')
#    3495     return
#    3496 except OSError as err:
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:1103, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1098 def report_error(self, message, *args, **kwargs):
#    1099     """
#    1100     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1101     in red if stderr is a tty file.
#    1102     """
# -> 1103     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File D:\miniconda3\envs\llm\lib\site-packages\yt_dlp\YoutubeDL.py:1042, in YoutubeDL.trouble(self, message, tb, is_error)
#    1040     else:
#    1041         exc_info = sys.exc_info()
# -> 1042     raise DownloadError(message, exc_info)
#    1043 self._download_retcode = 1
#
# DownloadError: ERROR: unable to download video data: HTTP Error 403: Forbidden
